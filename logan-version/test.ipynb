# %%
import util
import model

# %%
stocks  = ["MSFT","AAPL"]
sstudy_period = "1y"
data = util.get_data(stocks, sstudy_period)

# %%
# train-test split for time series

train_val_size = int(data.shape[1] * (2/3))
train_val, test = data[:,:train_val_size], data[:,train_val_size:]

print(train_val.shape)

# %%
train_size = int(train_val.shape[1] * 0.8)
train, validation = train_val[:,:train_size], train_val[:,train_size:]

# %%
print("train shape: {}".format(train.shape))
print("val shape: {}".format(validation.shape))
print("test shape: {}".format(test.shape))
